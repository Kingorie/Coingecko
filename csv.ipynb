# %%
import csv

# %%
filename = '/Users/kingori/Library/CloudStorage/GoogleDrive-kingori.ek@gmail.com/My Drive/Documents/Github/Coingecko/Reports/coingecko_20230129 15-32-15_page=10.csv'

fields = []
rows = []

with open(filename, 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    fields = next(csvreader)
    for row in csvreader:
        rows.append(row)
    print(f"Total number of rows are {csvreader.line_num}.")
# Out:
# Total number of rows are 100.

# %%
print('Field names are:' + ', '.join(field for field in fields))
# Out:
# Field names are:Coin, Ticker,  Price , 1h, 24h, 7d,  24h Volume ,  Mkt Cap ,  Fully Diluted Valuation

# %%
with open(filename, 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    fields = next(csvreader)
    print(','.join(fields))
    print()
    print("-------------------------------------------------------------------------------------------------")
    for row in csvreader:
        print(row)
# Out:
# Coin,Ticker, Price ,1h,24h,7d, 24h Volume , Mkt Cap , Fully Diluted Valuation
#
# -------------------------------------------------------------------------------------------------
# ['Vesta Stable', 'VST', ' 0.98 ', '-0.20%', '-0.10%', '-0.20%', ' 76,186 ', ' 11,028,341 ', ' -   ']
# ['Gelato', 'GEL', ' 0.17 ', '0.10%', '10.60%', '-1.60%', ' 58,684 ', ' 11,000,352 ', ' 70,447,780 ']
# ['Stader sFTMX', 'SFTMX', ' 0.51 ', '-0.30%', '3.30%', '39.80%', ' 67,899 ', ' 10,988,961 ', ' -   ']
# ['NUM Token', 'NUM', ' 0.04 ', '-0.10%', '9.20%', '14.40%', ' 1,102,537 ', ' 10,952,769 ', ' 35,580,927 ']
# ['Law Blocks', 'LBT', ' 0.15 ', '0.20%', '1.10%', '-3.70%', ' 90,761 ', ' 10,954,819 ', ' 146,064,257 ']
# ['Koinos', 'KOIN', ' 0.47 ', '1.20%', '5.00%', '-3.60%', ' 24,819 ', ' 10,931,786 ', ' 10,932,134 ']
# ['SWFTCOIN', 'SWFTC', ' 0.00 ', '0.30%', '-1.00%', '0.00%', ' 1,160,220 ', ' 10,922,124 ', ' -   ']
# ...

# %%
with open(filename, 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    fields = next(csvreader)
    for field in csvreader:
        print(field)
# Out:
# ['Vesta Stable', 'VST', ' 0.98 ', '-0.20%', '-0.10%', '-0.20%', ' 76,186 ', ' 11,028,341 ', ' -   ']
# ['Gelato', 'GEL', ' 0.17 ', '0.10%', '10.60%', '-1.60%', ' 58,684 ', ' 11,000,352 ', ' 70,447,780 ']
# ['Stader sFTMX', 'SFTMX', ' 0.51 ', '-0.30%', '3.30%', '39.80%', ' 67,899 ', ' 10,988,961 ', ' -   ']
# ['NUM Token', 'NUM', ' 0.04 ', '-0.10%', '9.20%', '14.40%', ' 1,102,537 ', ' 10,952,769 ', ' 35,580,927 ']
# ['Law Blocks', 'LBT', ' 0.15 ', '0.20%', '1.10%', '-3.70%', ' 90,761 ', ' 10,954,819 ', ' 146,064,257 ']
# ['Koinos', 'KOIN', ' 0.47 ', '1.20%', '5.00%', '-3.60%', ' 24,819 ', ' 10,931,786 ', ' 10,932,134 ']
# ['SWFTCOIN', 'SWFTC', ' 0.00 ', '0.30%', '-1.00%', '0.00%', ' 1,160,220 ', ' 10,922,124 ', ' -   ']
# ['Gravity Finance', 'GFI', ' 0.01 ', '4.10%', '6.80%', '32.50%', ' 28,403 ', ' 10,845,552 ', ' -   ']
# ['Oxen', 'OXEN', ' 0.18 ', '0.30%', '1.20%', '1.90%', ' 213,116 ', ' 10,832,831 ', ' -   ']
# ...
